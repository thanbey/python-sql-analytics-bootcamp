# %% [markdown]
# # Day 29 — LeetCode SQL: Analytics Interview Problems
# **Estimated time:** 2 hours (5 min per problem — set a timer)
# **Learning objectives:**
# 1. Solve medium/hard SQL problems using window functions, CTEs, and advanced aggregation
# 2. Practice the problem-solving approach expected in analytics engineering interviews
# 3. Understand why each SQL pattern appears in real analytics work
#
# ---
# > **Interview note:** analytics engineering interviews often include 2–4 SQL problems. Problems are designed to test: (1) ability to think in set-based logic, (2) knowledge of window functions, (3) ability to express business logic in SQL. Write comments explaining your reasoning — interviewers value thought process as much as correct output.

# %% [markdown]
# ## 0. Setup — Load DB

# %%
import duckdb
import pandas as pd
import numpy as np
from pathlib import Path

DATA = Path('../../data/raw')

# In-memory DuckDB — register CSVs as tables/views
con = duckdb.connect()

tables = {
    'materials':    'materials_inventory.csv',
    'sales_orders': 'sales_orders.csv',
    'cost_centers': 'cost_center_actuals.csv',
    'hr':           'hr_headcount.csv',
    'bw_kpis':      'bw_sales_kpis.csv',
}

dfs = {}
for tname, fname in tables.items():
    df = pd.read_csv(DATA / fname)
    con.register(tname, df)
    dfs[tname] = df

def q(sql):
    return con.sql(sql).df()

print('DB ready. Good luck!')

# %% [markdown]
# ## Problem 1 — Running Total of Revenue by Region
# **Difficulty:** Medium
#
# For each region, compute a cumulative (running) revenue total ordered by CAL_YEAR_MONTH. Show: REGION, CAL_YEAR_MONTH, monthly revenue, and running total.

# %%
# YOUR SOLUTION — set your 5-min timer now

q('''
-- YOUR SQL HERE
''')

# %% [markdown]
# ## Problem 2 — Rank Customers by Revenue Within Each Region
# **Difficulty:** Medium
#
# For each region, rank customers (KUNNR) by total revenue. Show the top 3 customers per region. Use DENSE_RANK.

# %%
# YOUR SOLUTION

q('''
-- YOUR SQL HERE
''')

# %% [markdown]
# ## Problem 3 — Month-over-Month Revenue Growth %
# **Difficulty:** Medium
#
# For each CAL_YEAR_MONTH, calculate total revenue and the % change from the prior month. Use LAG(). Handle the first row (no prior month) gracefully.

# %%
# YOUR SOLUTION

q('''
-- YOUR SQL HERE
''')

# %% [markdown]
# ## Problem 4 — First and Last Order Date per Customer
# **Difficulty:** Easy/Medium
#
# For each customer (KUNNR), find: first order date, last order date, total orders, and total revenue. Also calculate the 'customer age' in days (last - first order date).

# %%
# YOUR SOLUTION

q('''
-- YOUR SQL HERE
''')

# %% [markdown]
# ## Problem 5 — Top-N Per Group: Top 2 Materials by Revenue per Sales Org
# **Difficulty:** Medium
#
# Without using LIMIT (which ignores partitions), find the top 2 materials by total revenue within each sales org (VKORG). Use a window function.

# %%
# YOUR SOLUTION

q('''
-- YOUR SQL HERE
''')

# %% [markdown]
# ## Problem 6 — Median Salary by Org Unit (SQL Median Technique)
# **Difficulty:** Hard
#
# Calculate the median salary per org unit (ORGTX) without using a MEDIAN() function (SQLite does not have one). Use ROW_NUMBER and COUNT to identify the middle value(s).

# %%
# YOUR SOLUTION
# Hint: median = average of the middle row(s) when ordered by salary

q('''
-- YOUR SQL HERE
''')

# %% [markdown]
# ## Problem 7 — Gaps and Islands: Consecutive Months with Revenue > $1M
# **Difficulty:** Hard
#
# Find all 'islands' (consecutive months) where total revenue exceeds $1M per month. Report the island start date, end date, and length in months.

# %%
# YOUR SOLUTION
# Classic gaps-and-islands: subtract ROW_NUMBER to create group identifiers

q('''
-- YOUR SQL HERE
''')

# %% [markdown]
# ## Problem 8 — Self-Join: Employees Who Joined Same Month as Their Manager
# **Difficulty:** Medium
#
# The HR table has PLANS (position) and ORGEH (org unit). Simulate a manager relationship: the employee with the highest salary in each org unit is the 'manager'. Find employees (non-managers) who were hired in the same calendar month as their org's manager.

# %%
# YOUR SOLUTION

q('''
-- YOUR SQL HERE
''')

# %% [markdown]
# ## Problem 9 — CTE: Cost Center YTD Spend vs Annual Budget
# **Difficulty:** Medium
#
# Using a CTE, calculate YTD actual spend (periods 1-9) and the full-year plan for each cost center. Then compute the 'budget utilisation %' and flag any cost center above 80% utilised before period 9.

# %%
# YOUR SOLUTION

q('''
-- YOUR SQL HERE
''')

# %% [markdown]
# ## Problem 10 — Window Function: Previous Period Revenue for Each Row
# **Difficulty:** Medium
#
# For each row in bw_kpis, add a column showing the prior period's total revenue for the same VKORG and REGION. Use LAG() with a window partitioned by VKORG and REGION.

# %%
# YOUR SOLUTION

q('''
-- YOUR SQL HERE
''')

# %% [markdown]
# ## Problem 11 — Recursive CTE: Manager Chain
# **Difficulty:** Hard
#
# Using a recursive CTE, build an org hierarchy. Use the HR table: assume the highest-paid person per org unit is the 'team lead'. Build a 2-level hierarchy showing team_lead → all their org members.

# %%
# YOUR SOLUTION
# Hint: SQLite supports recursive CTEs with 'WITH RECURSIVE'

q('''
-- YOUR SQL HERE
''')

# %% [markdown]
# ## Problem 12 — Finding the Nth Highest Salary Without LIMIT/OFFSET
# **Difficulty:** Hard
#
# Find the 3rd highest distinct salary across all active employees. Do NOT use ORDER BY ... LIMIT. Use a subquery or window function approach.

# %%
# YOUR SOLUTION

q('''
-- YOUR SQL HERE
''')

# %% [markdown]
# ## Problem 13 — Detecting Consecutive Periods Without Orders (Gaps)
# **Difficulty:** Hard
#
# For each customer, find periods (months) where they placed orders in the month before and after but NOT in the current month. These are 'gap' months — potential churn indicators.

# %%
# YOUR SOLUTION

q('''
-- YOUR SQL HERE
''')

# %% [markdown]
# ## Problem 14 — Percentage Contribution Within Group
# **Difficulty:** Medium
#
# For each CAL_YEAR_MONTH, show each product division's (SPART) revenue AND its % share of that month's total revenue. Use a window function — no subquery needed.

# %%
# YOUR SOLUTION

q('''
-- YOUR SQL HERE
''')

# %% [markdown]
# ## Problem 15 — Multi-CTE Pipeline: Customer Lifetime Value Tier
# **Difficulty:** Hard
#
# Using multiple CTEs, calculate each customer's: (1) total revenue, (2) number of distinct order months, (3) average monthly revenue. Then assign a CLV tier: 'Platinum' (top 10%), 'Gold' (10-30%), 'Silver' (30-60%), 'Bronze' (bottom 40%).

# %%
# YOUR SOLUTION

q('''
-- YOUR SQL HERE
''')

# %% [markdown]
# ## Daily Prompt
# **Answer independently (no reference):**
#
# Pick 3 problems above that were hardest for you. For each one:
# 1. Re-solve it from scratch without looking at your solution
# 2. Write a 2-sentence explanation of the SQL concept used (as if explaining to a junior analyst)
# 3. Describe one real SAP analytics scenario where you'd use this exact pattern
